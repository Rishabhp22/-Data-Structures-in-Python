# %%
s = 'RIshaBh123@poDdaR'

choice = int(input("Enter 1 for Uppercase or 2 for lowercase: "))

if choice == 1:
    print(s.upper())
elif choice == 2:
    print(s.lower())
else:
    print('Invalid choice')
# Out:
# Invalid choice
